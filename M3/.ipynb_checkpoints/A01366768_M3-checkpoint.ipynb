# %% [markdown]
# # M3. Actividad
#
# Realizado por Andrea Corona Arroyo A01366768

# %% [markdown]
# Link a Github: https://github.com/AndreaCorona523/MultiAgentes.git

# %% [markdown]
# Modela, de manera individual, el sistema multiagente necesario para simular una intersección controlada por señales de semáforos inteligentes:
#
# - Mientras no haya un vehículo cercano, el semáforo estará en luz amarilla.
# - Cuando un vehículo se acerque a la intersección, enviará un mensaje con el tiempo estimado de arribo.
# - El semáforo dará luz verde al semáforo más cercano y establecerá un programa de luces a partir de ese punto para el resto de los vehículos.
#
# Detalla cuáles sería los agentes involucrados, qué tipo de agente sería y forma de interacción entre ellos. Adicionalmente, desarrolla una simulación implemente tu modelo.

# %% [markdown]
# # Agentes e Interacciones
#
# En el modelo que he diseñado, se cuentan con dos tipos de agente: Auto y Semáforo. Como sus nombres lo indican el primero representa los automóviles que circulan por la calle y el segundo son los semáforos que indican qué automóviles pueden cruzar y cuáles no.
#
# A continación se detalla el agente tipo Auto:
# Tipo de agente: Auto
# Medidas de rendimiento: Seguro y rápido, esto de manera que pueda a llegar a su destino sin inconvenientes y que no se quede detenido en un semáforo por mucho tiempo.
# Entorno: Calles, otro trafico (coches), semáforos.
# Actuadores: Dirección, freno, señal.
# Sensores: GPS, dado que posee instrucciones al girar hacia los lados.
#
# Este tipo de agentes es reactivo simple, dado que tiene reglas de reglas de situación-acción, las cuales son las siguientes:
# - En cada paso elige aleatoriamente si sigue derecho, da vuelta a la izquierda o a la derecha.
# - Si da vuelta a la izquierda, tiene que cambiar de carril, de manera que quede en el carril izquierdo de dicha calle.
# - Si da vuelta a la derecha, tiene que cambiar de carril, de manera que quede en el carril derecha de dicha calle.
# - Si el semáforo no está en rojo o el coche no se encuentra a punto de entrar al cruce, el auto puede avanzar.
# - Si el auto desea moverse a un lugar, donde se encuentra otro auto, este espera en su posición.
#
# A continación se detalla el agente tipo Semáforo:
# Tipo de agente: Semáforo
# Medidas de rendimiento: Movibilidad vehicular eficiente, sin tráfico pesado.
# Entorno: Calles, coches, otros semáforos.
# Actuadores: Luz.
# Sensores: Sensor de señal.
#
# Este tipo de agentes es reactivo simple, dado que tiene reglas de reglas de situación-acción, las cuales son las siguientes:
# - Si hay un agente a 2 casillas o menos, cambia su luz a verde.
# - Si hay autos cerca de dos semáforos en calles con direcciones opuestas, ambos se van a prender.
# - Si detecta una señal, sólo se cambiará de verde a rojo, hasta que haya detectado que el cruce esté libre (sin autos en circulación).
# - Si no hay autos cercanos (a dos casillas o menos), el semáforo permanece en amarillo.
#
# Por otro lado, el modelo va a ser la calle por la que circulan los automóviles.
#
# Las interacciones entre ellos, se definen por las reglas establecidas previamente. En otras palabras, la interacción principal será que el coche envía una señal que el semáforo recibe y este último actúa en consecuencia, así como el estado del semáforo, afecta el comportamiento del semáforo.

# %% [markdown]
# ## Imports
#
# Antes de empezar a crear el modelo de los robots de limpieza con multiagentes es necesario tener instalado los siguientes paquetes:
# - `python`
# - `mesa`: el framework de Python para el modelado de agentes.
# - `numpy`
# - `matplotlib`
#
# Para poder modelar el juego de la vida usando el framework de `mesa` es necesario importar dos clases: una para el modelo general, y otro para los agentes.

# %%
# La clase `Model` se hace cargo de los atributos a nivel del modelo, maneja los agentes. 
# Cada modelo puede contener múltiples agentes y todos ellos son instancias de la clase `Agent`.
from mesa import Agent, Model 

# Debido a que no se permitirá más de un agente por celda elegimos `SingleGrid`.
from mesa.space import SingleGrid

# Con `SimultaneousActivation` hacemos que todos los agentes se activen de manera simultanea.
from mesa.time import SimultaneousActivation

# Vamos a hacer uso de `DataCollector` para obtener el grid completo cada paso (o generación) y lo usaremos para graficarlo.
from mesa.datacollection import DataCollector

# mathplotlib lo usamos para graficar/visualizar como evoluciona el autómata celular.
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.rcParams["animation.html"] = "jshtml"
matplotlib.rcParams['animation.embed_limit'] = 2**128

# Definimos los siguientes paquetes para manejar valores númericos.
import numpy as np
import pandas as pd
import random

# Definimos otros paquetes que vamos a usar para medir el tiempo de ejecución de nuestro algoritmo.
import time
import datetime

# %% [markdown]
# # Creación del Modelo

# %%
def obtenerCalle(model):
    '''
    Esta es una función auxiliar que nos permite guardar el grid para cada uno de los agentes.
    param model: El modelo del cual optener el grid.
    return una matriz con la información del grid del agente.
    '''
    grid = np.zeros((model.grid.width, model.grid.height))
    for cell in model.grid.coord_iter():
        cell_content, x, y = cell
        if isinstance(cell_content, CarAgent):
            grid[x][y] = 0
        elif isinstance(cell_content, TrafficLight):
            grid[x][y] = cell_content.status
        else:
            grid[x][y] = 1
    return grid

class CarAgent(Agent):
    '''
    Representa a un coche.
    '''
    def __init__(self, unique_id, model,orientation, direction, lane):
        '''
        Agente representa un automóvil, se inicializa con un id, con el numero de movimientos realizados en 0, 
        con su siguiente posición en None, su orientación (V - vertical y H - horizontal),
        su direccion (U - arriba y D - abajo) y su carril (R- derecha, L - izquierda) y el tipo de movimiento que va a 
        realizar (F - adelante, TR - vuelta a la derecha y TL - vuelta a la izquierda) y una lista vacía de pasos 
        siguientes
        '''
        
        super().__init__(unique_id, model)
        self.numMovimientos = 0
        self.nextPos = None
        self.orientation = orientation
        self.direction = direction
        self.lane = lane
        self.nextSteps = []
        self.movement = "F"
        self.crossed = False
        self.signalSent = False
        self.arrived = False
    
    
    def moveForward(self):
        '''
        Este método se utiliza para avanzar el agente
        '''
        nextX = self.pos[0]
        nextY = self.pos[1]
        if self.orientation == "V":
            if self.direction == "U":
                nextX -= 1
            else:
                nextX += 1
        else:
            if self.direction == "U":
                nextY += 1
            else:
                nextY -= 1
        self.nextPos = (nextX, nextY)
           
    def turnLeft(self): 
        '''
        Este método se utiliza para girar el agente a la izquierda
        '''
        if self.orientation == "V":
            self.orientation = "H"
            if self.direction == "U":
                self.direction = "D"
            else:
                self.direction = "U"
        else:
            self.orientation = "V"
    
            

    def turnRight(self):
        '''
        Este método se utiliza para girar el agente a la derecha
        '''
        if self.orientation == "V":
            self.orientation = "H"
        else:
            self.orientation = "V"
            if self.direction == "U":
                self.direction = "D"
            else:
                self.direction = "U"
       
    def findClosestTrafficLight(self):
        '''
        Este método se utiliza para encontrar el semáforo más cercano
        '''
        if self.orientation == "V":
            if self.direction == "U":
                return 3
            return 1
        else:
            if self.direction == "U":
                return 0
            return 2
        
    def closestTrafficLight(self):
        '''
        Este método se utiliza para calcular la distancia entre el auto y el semáforo
        '''
        idx = self.findClosestTrafficLight()
        if idx % 2 == 0: 
            return idx,  abs(self.pos[1] - model.trafficLights[idx].pos[1])
        return idx, abs(self.pos[0] - model.trafficLights[idx].pos[0])
    
    def sendSignal(self):
        '''
        Este método se utiliza para enviar la señal al semáforo.
        '''
        idx, dist = self.closestTrafficLight()
        if dist <= 2:
            if not self.unique_id in model.trafficLights[idx].signals and not model.carInIntersection(self):
                model.trafficLights[idx].signals.append(self.unique_id)
                
                print("soy", self.unique_id, "y el semáforo que me toca es ", model.trafficLights[idx].unique_id, idx, "y envie señal")
                
                return True
        return False
        
    def checkTrafficLight(self):
        '''
        Este método se utiliza para revisar si el semáforo más cercano está en rojo y si puede avanzar
        '''
        idx, dist = self.closestTrafficLight()
        if model.trafficLights[idx].status == model.trafficLights[idx].RED and dist == 0 and len(self.nextSteps) == 0:
            return False
        return True

    def changeLane(self):
        '''
        Este método se utiliza para cambiar de carril
        '''
        nextX = self.pos[0]
        nextY = self.pos[1]
        
        if self.lane == "R":
            self.lane = "L"
            if self.direction == "U":
                if self.orientation == "H":
                    nextX -= 1 
                else: 
                    nextY -= 1
            else:
                if self.orientation == "H":
                    nextX += 1 
                else:
                    nextY += 1
        else:
            self.lane = "R"
            if self.direction == "U":
                if self.orientation == "H":
                    nextX += 1
                else:
                    nextY += 1
            else:
                if self.orientation == "H":
                    nextX -= 1
                else: 
                    nextY -= 1 
        
        self.nextPos = (nextX, nextY)
                 
    def movementTurn(self, direc):
        '''
        Este método se utiliza para realizar la vuelta dependiendo si es a la izquierda o derecha
        '''
        if direc == "TL":
            if self.lane == "R":
                self.changeLane()
                return "C"
            else:
                self.nextSteps.extend(["F", "TL"])
        else:
            if self.lane == "L":
                self.changeLane()
                return "C"
            else:
                self.nextSteps.extend(["F","F", "F", "TR"])
            
    
    def step(self):
        '''
        En este método el agente realiza las acciones del agente por cada paso.
        '''
        if self.signalSent:
            idx, dist = self.closestTrafficLight()
            if dist == 0:
                self.arrived = True
            elif self.arrived and model.carInIntersection(self):
                self.crossed = False
            elif self.arrived:
                self.crossed = True
        else:
            self.crossed = False
            self.arrived = False
        
        move = "S"
        #Checa el siguiente movimiento del auto
        if self.checkTrafficLight():
            move = "F"
            if self.closestTrafficLight()[1] == 0 and self.movement == "F":
                self.movement = random.choice(["F", "TR", "TL"])
                
            if (self.movement == "TL" or self.movement == "TR") and len(self.nextSteps) == 0:
                    move = self.movementTurn(self.movement)
                
            if len(self.nextSteps) > 0:
                #print(self.nextSteps)
                move = self.nextSteps.pop(0)

        
        #print(" self.movement ", self.movement, "move ", move)
                
        if move == "TR":
            self.turnRight()
            self.movement = "F"
        elif move == "TL":
            self.turnLeft()
            self.movement = "F"
            
       
        #print(self.unique_id, self.orientation, self.direction, self.lane)
        #print("-----")
        
        if (self.movement == "F" or move == "F") and move != "S":
            self.moveForward()
            
             
        #Actualizar la posición en la lista de posiciones de los autos
        
        carsPositions = [car.nextPos for car in model.cars if car != self]
        
        if self.nextPos in carsPositions:
            self.nextPos = self.pos
            if move == "C":
                if self.lane == "R":
                    self.lane = "L"
                else:
                    self.lane = "R"
        
        print("self.pos", self.pos)
        print("self.movement ", self.movement, "move ", move)
        print("self.next pos", self.nextPos)
        
        if self.sendSignal():
            self.signalSent = True
            

    def advance(self):
        '''
        Define el nuevo estado calculado del método step.
        '''
        self.model.grid.move_agent(self, self.nextPos)
        self.numMovimientos += 1

class TrafficLight(Agent):
    '''
    Representa a un semáforo con los tres colores verde, amarillo y rojo.
    '''
    GREEN = 0.3
    YELLOW = 0.52
    RED = 0.7
    
    def __init__(self, unique_id, model):
        '''
        Agente representa una celda del piso, se inicializa con un id y 
        con el status de rojo
        '''
        super().__init__(unique_id, model)
        self.status = self.YELLOW
        self.signals = []
        
    def addToQueue(self):
        '''
        Este método se utiliza para agregar el semáforo a la fila de espera en caso de que reciba señales,
        o quitarse en caso de que ya no tenga señales. Asimismo, si no tiene señales se agrega a la lista 
        del modelo que almacena los semáforos libres.
        '''
        if len(self.signals) > 0:
            if not self.unique_id in model.queueTrafficLights:
                model.queueTrafficLights.append(self.unique_id)
            if self.unique_id in model.freeTrafficLights:
                model.freeTrafficLights.remove(self.unique_id)
        else:
            if self.unique_id in model.queueTrafficLights:
                model.queueTrafficLights.remove(self.unique_id)
            if not self.unique_id in model.freeTrafficLights:
                model.freeTrafficLights.append(self.unique_id)
    
    
    def checkDistFromCar(self, idxTF):
        '''
        Este método se utiliza para revisar la distancia de un auto con respecto a un 
        semáforo determinado
        '''
        idxSelf = model.findTrafficLightIndex(self.unique_id) 
        for car in model.cars:
            idx, dist = car.closestTrafficLight()
            if idx == idxSelf and not model.carInIntersection(car):
                return dist
        return -1
    
    def updateSignals(self):
        '''
        Este método se utiliza para actualizar las señales de los semáforos
        '''
        idxSelf = model.findTrafficLightIndex(self.unique_id) 
        for car in model.cars:
            idx, dist = car.closestTrafficLight()
            if idx != idxSelf and car.unique_id in self.signals and not model.carInIntersection(car):
                self.signals.remove(car.unique_id)
            if idx == idxSelf and car.unique_id in self.signals and car.crossed:
                self.signals.remove(car.unique_id)
                car.signalSent = False

        print("signals", self.signals)
        
        
class StreetModel(Model):
    '''
    Define el modelo de la calle donde se encuentran los autos.
    '''
    def __init__(self, num, width, height):
        self.grid = SingleGrid(width, height, True)
        self.width = height
        self.height = height
        self.maxNumCars = num
        self.midWidth = self.width // 2
        self.midHeight = self.height // 2
        self.schedule = SimultaneousActivation(self)
        
        
        self.cars = []
        self.trafficLights = []
        self.queueTrafficLights = []
        self.freeTrafficLights = []
        
        
        self.running = True
        self.arrived = False
        self.passed = False
        self.arrived2 = False
        self.passed2 = False
        

            
        #Posicionar semáforos 

        a = TrafficLight("trafLight Sup Left", self)
        self.grid.place_agent(a, (self.midWidth - 3, self.midHeight - 3))
        self.schedule.add(a)
        self.trafficLights.append(a)
        
        
        b = TrafficLight("trafLight Sup Right", self)
        self.grid.place_agent(b, (self.midWidth - 3, self.midHeight + 2))
        self.schedule.add(b)
        self.trafficLights.append(b)
        
        c = TrafficLight("trafLight Inf Right", self)
        self.grid.place_agent(c, (self.midWidth + 2, self.midHeight + 2))
        self.schedule.add(c)
        self.trafficLights.append(c)
        
        d = TrafficLight("trafLight Inf Left", self)
        self.grid.place_agent(d, (self.midWidth + 2, self.midHeight - 3))
        self.schedule.add(d)
        self.trafficLights.append(d) 
        
        
        #Posicionar autos 
        maxNumCars = min(8, self.maxNumCars)
        numCars = random.randint(1, maxNumCars)
        self.addCars(numCars)
        
        
        # Aquí definimos con colector para obtener la habitación y el número de movimientos totales.
        self.datacollector = DataCollector(
            model_reporters={'Habitacion': obtenerCalle},
            agent_reporters={'Movimientos': lambda a: getattr(a, 'numMovimientos', None)},
        )
        
    
    def step(self):
        '''
        En cada paso el colector tomará la información que se definió y almacenará el grid para luego graficarlo.
        '''
        #Se verifica si la intersección está libre para realizar el cambio del semáforo
        print("iter --------------------------------------")
        
        
        self.changeTrafficLight()
        
        self.datacollector.collect(self)
        self.schedule.step()
        
        #Se agregan la cantidad de autos faltantes
        carsLeft = self.maxNumCars - len(self.cars)
        if  carsLeft > 0 :
            carsLeft = min(8, carsLeft)
            numCars = random.randint(1, carsLeft)
            self.addCars(numCars)
        
        print("iter --------------------------------------")
        
    def addCars(self, n):
        '''
        Este método se utiliza para agregar n cantidad de autos.
        '''
        for n in range(n):
            approved = False
            while not approved:
                pos = random.randint(self.midWidth - 2, self.midWidth + 1)
                orientation = random.choice(["H","V"])
                if pos < self.midWidth:
                    direction = "U" 
                    if orientation == "H":
                        coords = (pos, 0)
                    else: 
                        coords = (self.height - 1, pos)

                else:
                    direction = "D"
                    if orientation == "H":
                        coords = (pos, self.width - 1)
                    else: 
                        coords = (0, pos)

                if pos - 1 == self.midWidth - 3 or pos + 1 == self.midWidth + 2:
                    lane = "L"
                else:
                    lane = "R"
                    
                
                carsPositions = [car.pos for car in self.cars]
                
                if not coords in carsPositions:
                    approved = True
            
            
            a = CarAgent(len(self.cars), self, orientation, direction, lane)
            self.grid.place_agent(a, coords)
            self.schedule.add(a)
            self.cars.append(a)
    
    def intersectionEmpty(self):
        '''
        Este método se utiliza para verificar el cruce está libre.
        '''
        for i in range(self.midWidth - 2, self.midWidth + 2):
            for j in range(self.midHeight - 2, self.midHeight + 2):
                if not self.grid.is_cell_empty((i,j)):
                    return False
        return True
    
    def carInIntersection(self, car):
        for i in range(self.midWidth - 2, self.midWidth + 2):
            for j in range(self.midHeight - 2, self.midHeight + 2):
                if car.pos == (i,j):
                    return True
        return False
        
        
                
    def findTrafficLightIndex(self, nameTrafficLight):
        for i in range(len(self.trafficLights)):
                if self.trafficLights[i].unique_id == nameTrafficLight:
                    return i

    def changeTrafficLight(self):
        '''
        Este método se utiliza para realizar el cambio de los semáforos.
        '''
        #Se actualiza la lista de señales del semáforo
        for idxTF in range(len(self.trafficLights)):
            self.trafficLights[idxTF].updateSignals()
            self.trafficLights[idxTF].addToQueue()
            
            if self.trafficLights[idxTF].unique_id in self.queueTrafficLights:
                self.trafficLights[idxTF].status = self.trafficLights[idxTF].RED
            if self.trafficLights[idxTF].unique_id in self.freeTrafficLights:
                self.trafficLights[idxTF].status = self.trafficLights[idxTF].YELLOW
                
            
        if len(self.queueTrafficLights) > 0:
            firstTrafficLightName = self.queueTrafficLights[0]
            idx = self.findTrafficLightIndex(firstTrafficLightName)
            self.trafficLights[idx].status = self.trafficLights[idx].GREEN
            
        
        print("queue", self.queueTrafficLights)
        print("free",self.freeTrafficLights)

# %% [markdown]
# A continuación se corre el modelo:

# %%
# Definimos el tamaño del Grid
M = 16
N = 16

# Definimos el número de agentes
NUM_AGENTS = 5

# Definimos tiempo máximo (segundos)
MAX_TIME = 0.02

# Registramos el tiempo de inicio y corremos el modelo
num_generations = 0

start_time = time.time()
model = StreetModel(NUM_AGENTS, M, N)
#while time.time() - start_time < MAX_TIME:

while num_generations < 100:
    num_generations += 1
    model.step()
    end_time = time.time()
# Out:
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals []
# queue []
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 0)
# self.movement  F move  F
# self.next pos (6, 1)
# self.pos (8, 15)
# self.movement  F move  F
# self.next pos (8, 14)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals []
# queue []
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 1)
# self.movement  F move  F
# self.next pos (6, 2)
# self.pos (8, 14)
# self.movement  F move  F
# self.next pos (8, 13)
# self.pos (6, 0)
# self.movement  F move  F
# self.next pos (6, 1)
# self.pos (9, 15)
# self.movement  F move  F
# self.next pos (9, 14)
# self.pos (15, 6)
# self.movement  F move  F
# self.next pos (14, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals []
# queue []
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 2)
# self.movement  F move  F
# self.next pos (6, 3)
# self.pos (8, 13)
# self.movement  F move  F
# self.next pos (8, 12)
# self.pos (6, 1)
# self.movement  F move  F
# self.next pos (6, 2)
# self.pos (9, 14)
# self.movement  F move  F
# self.next pos (9, 13)
# self.pos (14, 6)
# self.movement  F move  F
# self.next pos (13, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals []
# queue []
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 3)
# self.movement  F move  F
# self.next pos (6, 4)
# soy 0 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (8, 12)
# self.movement  F move  F
# self.next pos (8, 11)
# soy 1 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (6, 2)
# self.movement  F move  F
# self.next pos (6, 3)
# self.pos (9, 13)
# self.movement  F move  F
# self.next pos (9, 12)
# self.pos (13, 6)
# self.movement  F move  F
# self.next pos (12, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals [1]
# signals []
# queue ['trafLight Sup Left', 'trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left']
# self.pos (6, 4)
# self.movement  F move  F
# self.next pos (6, 5)
# self.pos (8, 11)
# self.movement  F move  F
# self.next pos (8, 10)
# self.pos (6, 3)
# self.movement  F move  F
# self.next pos (6, 4)
# soy 2 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (9, 12)
# self.movement  F move  F
# self.next pos (9, 11)
# soy 3 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (12, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# soy 4 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 5)
# self.movement  F move  F
# self.next pos (6, 6)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (6, 4)
# self.movement  F move  F
# self.next pos (6, 5)
# self.pos (9, 11)
# self.movement  F move  F
# self.next pos (9, 10)
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 6)
# self.movement  F move  F
# self.next pos (6, 7)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (6, 5)
# self.movement  TR move  C
# self.next pos (7, 5)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 7)
# self.movement  F move  F
# self.next pos (6, 8)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (7, 5)
# self.movement  TR move  F
# self.next pos (7, 6)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 8)
# self.movement  F move  F
# self.next pos (6, 9)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (7, 6)
# self.movement  TR move  F
# self.next pos (7, 7)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 9)
# self.movement  F move  F
# self.next pos (6, 10)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (7, 7)
# self.movement  TR move  F
# self.next pos (7, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0, 2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 10)
# self.movement  F move  F
# self.next pos (6, 11)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (7, 8)
# self.movement  F move  TR
# self.next pos (8, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 11)
# self.movement  F move  F
# self.next pos (6, 12)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (8, 8)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [2]
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right']
# self.pos (6, 12)
# self.movement  F move  F
# self.next pos (6, 13)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (10, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 13)
# self.movement  F move  F
# self.next pos (6, 14)
# self.pos (8, 10)
# self.movement  TR move  F
# self.next pos (8, 9)
# self.pos (10, 8)
# self.movement  F move  F
# self.next pos (11, 8)
# self.pos (9, 10)
# self.movement  F move  F
# self.next pos (9, 9)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 14)
# self.movement  F move  F
# self.next pos (6, 15)
# self.pos (8, 9)
# self.movement  TR move  F
# self.next pos (8, 8)
# self.pos (11, 8)
# self.movement  F move  F
# self.next pos (12, 8)
# self.pos (9, 9)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 15)
# self.movement  F move  F
# self.next pos (6, 16)
# self.pos (8, 8)
# self.movement  TR move  F
# self.next pos (8, 7)
# self.pos (12, 8)
# self.movement  F move  F
# self.next pos (13, 8)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (9, 7)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 0)
# self.movement  F move  F
# self.next pos (6, 1)
# self.pos (8, 7)
# self.movement  F move  TR
# self.next pos (7, 7)
# self.pos (13, 8)
# self.movement  F move  F
# self.next pos (14, 8)
# self.pos (9, 7)
# self.movement  F move  F
# self.next pos (9, 6)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 1)
# self.movement  F move  F
# self.next pos (6, 2)
# self.pos (7, 7)
# self.movement  F move  F
# self.next pos (6, 7)
# self.pos (14, 8)
# self.movement  F move  F
# self.next pos (15, 8)
# self.pos (9, 6)
# self.movement  F move  F
# self.next pos (9, 5)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [1, 3]
# signals [4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left']
# self.pos (6, 2)
# self.movement  F move  F
# self.next pos (6, 3)
# self.pos (6, 7)
# self.movement  F move  F
# self.next pos (5, 7)
# self.pos (15, 8)
# self.movement  F move  F
# self.next pos (16, 8)
# self.pos (9, 5)
# self.movement  F move  F
# self.next pos (9, 4)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals [4]
# queue ['trafLight Inf Left']
# free ['trafLight Sup Right', 'trafLight Sup Left', 'trafLight Inf Right']
# self.pos (6, 3)
# self.movement  F move  F
# self.next pos (6, 4)
# soy 0 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (5, 7)
# self.movement  F move  F
# self.next pos (4, 7)
# self.pos (0, 8)
# self.movement  F move  F
# self.next pos (1, 8)
# self.pos (9, 4)
# self.movement  F move  F
# self.next pos (9, 3)
# self.pos (10, 6)
# self.movement  F move  F
# self.next pos (9, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals []
# signals [4]
# queue ['trafLight Inf Left', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Right']
# self.pos (6, 4)
# self.movement  F move  F
# self.next pos (6, 5)
# self.pos (4, 7)
# self.movement  F move  F
# self.next pos (3, 7)
# self.pos (1, 8)
# self.movement  F move  F
# self.next pos (2, 8)
# self.pos (9, 3)
# self.movement  F move  F
# self.next pos (9, 2)
# self.pos (9, 6)
# self.movement  F move  F
# self.next pos (8, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals []
# signals [4]
# queue ['trafLight Inf Left', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Right']
# self.pos (6, 5)
# self.movement  F move  S
# self.next pos (6, 5)
# self.pos (3, 7)
# self.movement  F move  F
# self.next pos (2, 7)
# self.pos (2, 8)
# self.movement  F move  F
# self.next pos (3, 8)
# self.pos (9, 2)
# self.movement  F move  F
# self.next pos (9, 1)
# self.pos (8, 6)
# self.movement  F move  F
# self.next pos (7, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals []
# signals [4]
# queue ['trafLight Inf Left', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Right']
# self.pos (6, 5)
# self.movement  F move  S
# self.next pos (6, 5)
# self.pos (2, 7)
# self.movement  F move  F
# self.next pos (1, 7)
# self.pos (3, 8)
# self.movement  F move  F
# self.next pos (4, 8)
# soy 2 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# self.pos (9, 1)
# self.movement  F move  F
# self.next pos (9, 0)
# self.pos (7, 6)
# self.movement  F move  F
# self.next pos (6, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals []
# signals [4]
# queue ['trafLight Inf Left', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Right']
# self.pos (6, 5)
# self.movement  F move  S
# self.next pos (6, 5)
# self.pos (1, 7)
# self.movement  F move  F
# self.next pos (0, 7)
# self.pos (4, 8)
# self.movement  F move  F
# self.next pos (5, 8)
# soy 2 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# self.pos (9, 0)
# self.movement  F move  F
# self.next pos (9, -1)
# self.pos (6, 6)
# self.movement  F move  F
# self.next pos (5, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [2]
# signals []
# signals [4]
# queue ['trafLight Inf Left', 'trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Right']
# self.pos (6, 5)
# self.movement  F move  S
# self.next pos (6, 5)
# self.pos (0, 7)
# self.movement  F move  F
# self.next pos (-1, 7)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (9, 15)
# self.movement  F move  F
# self.next pos (9, 14)
# self.pos (5, 6)
# self.movement  F move  F
# self.next pos (4, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [2]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 5)
# self.movement  TL move  F
# self.next pos (6, 6)
# self.pos (15, 7)
# self.movement  F move  F
# self.next pos (14, 7)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (9, 14)
# self.movement  F move  F
# self.next pos (9, 13)
# self.pos (4, 6)
# self.movement  F move  F
# self.next pos (3, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [2]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 6)
# self.movement  F move  TL
# self.next pos (5, 6)
# self.pos (14, 7)
# self.movement  F move  F
# self.next pos (13, 7)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (9, 13)
# self.movement  F move  F
# self.next pos (9, 12)
# self.pos (3, 6)
# self.movement  F move  F
# self.next pos (2, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Inf Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (5, 6)
# self.movement  F move  F
# self.next pos (4, 6)
# self.pos (13, 7)
# self.movement  F move  F
# self.next pos (12, 7)
# self.pos (5, 8)
# self.movement  F move  F
# self.next pos (6, 8)
# self.pos (9, 12)
# self.movement  F move  F
# self.next pos (9, 11)
# soy 3 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (2, 6)
# self.movement  F move  F
# self.next pos (1, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals [3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (4, 6)
# self.movement  F move  F
# self.next pos (3, 6)
# self.pos (12, 7)
# self.movement  F move  F
# self.next pos (11, 7)
# soy 1 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (6, 8)
# self.movement  F move  F
# self.next pos (7, 8)
# self.pos (9, 11)
# self.movement  F move  F
# self.next pos (9, 10)
# self.pos (1, 6)
# self.movement  F move  F
# self.next pos (0, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals [3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (3, 6)
# self.movement  F move  F
# self.next pos (2, 6)
# self.pos (11, 7)
# self.movement  F move  F
# self.next pos (10, 7)
# soy 1 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (8, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (0, 6)
# self.movement  F move  F
# self.next pos (-1, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals [3]
# signals [1]
# queue ['trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left']
# self.pos (2, 6)
# self.movement  F move  F
# self.next pos (1, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (8, 8)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (15, 6)
# self.movement  F move  F
# self.next pos (14, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals [3]
# signals [1]
# queue ['trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left']
# self.pos (1, 6)
# self.movement  F move  F
# self.next pos (0, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (10, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (14, 6)
# self.movement  F move  F
# self.next pos (13, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals [3]
# signals [1]
# queue ['trafLight Sup Right', 'trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left']
# self.pos (0, 6)
# self.movement  F move  F
# self.next pos (-1, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (10, 8)
# self.movement  F move  F
# self.next pos (11, 8)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (13, 6)
# self.movement  F move  F
# self.next pos (12, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (15, 6)
# self.movement  F move  F
# self.next pos (14, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (11, 8)
# self.movement  F move  F
# self.next pos (12, 8)
# self.pos (9, 10)
# self.movement  TR move  C
# self.next pos (8, 10)
# self.pos (12, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# soy 4 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (14, 6)
# self.movement  F move  F
# self.next pos (13, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (12, 8)
# self.movement  F move  F
# self.next pos (13, 8)
# self.pos (8, 10)
# self.movement  TR move  F
# self.next pos (8, 9)
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (13, 6)
# self.movement  F move  F
# self.next pos (12, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (13, 8)
# self.movement  F move  F
# self.next pos (14, 8)
# self.pos (8, 9)
# self.movement  TR move  F
# self.next pos (8, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (12, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# soy 0 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (14, 8)
# self.movement  F move  F
# self.next pos (15, 8)
# self.pos (8, 8)
# self.movement  TR move  F
# self.next pos (8, 7)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# soy 0 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (15, 8)
# self.movement  F move  F
# self.next pos (16, 8)
# self.pos (8, 7)
# self.movement  F move  TR
# self.next pos (7, 7)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4, 0]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (0, 8)
# self.movement  F move  F
# self.next pos (1, 8)
# self.pos (7, 7)
# self.movement  F move  F
# self.next pos (6, 7)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [3]
# signals [1, 4, 0]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (1, 8)
# self.movement  F move  F
# self.next pos (2, 8)
# self.pos (6, 7)
# self.movement  F move  F
# self.next pos (5, 7)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right']
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# self.pos (10, 7)
# self.movement  TR move  F
# self.next pos (9, 7)
# self.pos (2, 8)
# self.movement  F move  F
# self.next pos (3, 8)
# self.pos (5, 7)
# self.movement  F move  F
# self.next pos (4, 7)
# self.pos (10, 6)
# self.movement  TR move  C
# self.next pos (10, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right']
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (10, 6)
# self.pos (9, 7)
# self.movement  TR move  F
# self.next pos (8, 7)
# self.pos (3, 8)
# self.movement  F move  F
# self.next pos (4, 8)
# soy 2 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# self.pos (4, 7)
# self.movement  F move  F
# self.next pos (3, 7)
# self.pos (10, 7)
# self.movement  TR move  F
# self.next pos (9, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (10, 6)
# self.movement  TR move  C
# self.next pos (10, 7)
# self.pos (8, 7)
# self.movement  TR move  F
# self.next pos (7, 7)
# self.pos (4, 8)
# self.movement  F move  F
# self.next pos (5, 8)
# self.pos (3, 7)
# self.movement  F move  F
# self.next pos (2, 7)
# self.pos (9, 7)
# self.movement  TR move  F
# self.next pos (8, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (10, 7)
# self.movement  TR move  F
# self.next pos (9, 7)
# self.pos (7, 7)
# self.movement  F move  TR
# self.next pos (7, 8)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (2, 7)
# self.movement  F move  F
# self.next pos (1, 7)
# self.pos (8, 7)
# self.movement  TR move  F
# self.next pos (7, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (9, 7)
# self.movement  TR move  F
# self.next pos (8, 7)
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (7, 9)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (1, 7)
# self.movement  F move  F
# self.next pos (0, 7)
# self.pos (7, 7)
# self.movement  F move  TR
# self.next pos (7, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [1, 4, 0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (8, 7)
# self.movement  TR move  F
# self.next pos (7, 7)
# self.pos (7, 9)
# self.movement  F move  F
# self.next pos (7, 10)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (0, 7)
# self.movement  F move  F
# self.next pos (-1, 7)
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (7, 9)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [4, 0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 7)
# self.movement  F move  TR
# self.next pos (7, 8)
# self.pos (7, 10)
# self.movement  F move  F
# self.next pos (7, 11)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (15, 7)
# self.movement  F move  F
# self.next pos (14, 7)
# self.pos (7, 9)
# self.movement  F move  F
# self.next pos (7, 10)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (7, 9)
# self.pos (7, 11)
# self.movement  F move  F
# self.next pos (7, 12)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (14, 7)
# self.movement  F move  F
# self.next pos (13, 7)
# self.pos (7, 10)
# self.movement  F move  F
# self.next pos (7, 11)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [0]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 9)
# self.movement  F move  F
# self.next pos (7, 10)
# self.pos (7, 12)
# self.movement  F move  F
# self.next pos (7, 13)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (13, 7)
# self.movement  F move  F
# self.next pos (12, 7)
# self.pos (7, 11)
# self.movement  F move  F
# self.next pos (7, 12)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (7, 10)
# self.movement  F move  F
# self.next pos (7, 11)
# self.pos (7, 13)
# self.movement  F move  F
# self.next pos (7, 14)
# self.pos (5, 8)
# self.movement  TR move  F
# self.next pos (6, 8)
# self.pos (12, 7)
# self.movement  F move  F
# self.next pos (11, 7)
# soy 3 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (7, 12)
# self.movement  F move  F
# self.next pos (7, 13)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (7, 11)
# self.movement  F move  F
# self.next pos (7, 12)
# self.pos (7, 14)
# self.movement  F move  F
# self.next pos (7, 15)
# self.pos (6, 8)
# self.movement  TR move  F
# self.next pos (7, 8)
# self.pos (11, 7)
# self.movement  F move  F
# self.next pos (10, 7)
# soy 3 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (7, 13)
# self.movement  F move  F
# self.next pos (7, 14)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [3]
# queue ['trafLight Sup Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 12)
# self.movement  F move  F
# self.next pos (7, 13)
# self.pos (7, 15)
# self.movement  F move  F
# self.next pos (7, 16)
# self.pos (7, 8)
# self.movement  TR move  F
# self.next pos (8, 8)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (7, 14)
# self.movement  F move  F
# self.next pos (7, 15)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [3]
# queue ['trafLight Sup Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 13)
# self.movement  F move  F
# self.next pos (7, 14)
# self.pos (7, 0)
# self.movement  F move  F
# self.next pos (7, 1)
# self.pos (8, 8)
# self.movement  F move  TR
# self.next pos (8, 7)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (7, 15)
# self.movement  F move  F
# self.next pos (7, 16)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [3]
# queue ['trafLight Sup Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 14)
# self.movement  F move  F
# self.next pos (7, 15)
# self.pos (7, 1)
# self.movement  F move  F
# self.next pos (7, 2)
# self.pos (8, 7)
# self.movement  F move  F
# self.next pos (8, 6)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (7, 0)
# self.movement  F move  F
# self.next pos (7, 1)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [2]
# signals []
# signals [3]
# queue ['trafLight Sup Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (7, 15)
# self.movement  F move  F
# self.next pos (7, 16)
# self.pos (7, 2)
# self.movement  F move  F
# self.next pos (7, 3)
# self.pos (8, 6)
# self.movement  F move  F
# self.next pos (8, 5)
# self.pos (10, 7)
# self.movement  F move  S
# self.next pos (10, 7)
# self.pos (7, 1)
# self.movement  F move  F
# self.next pos (7, 2)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals [3]
# queue ['trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Sup Right']
# self.pos (7, 0)
# self.movement  F move  F
# self.next pos (7, 1)
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 1 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (8, 5)
# self.movement  F move  F
# self.next pos (8, 4)
# self.pos (10, 7)
# self.movement  TL move  C
# self.next pos (10, 6)
# self.pos (7, 2)
# self.movement  F move  F
# self.next pos (7, 3)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals []
# signals [3]
# queue ['trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Sup Right']
# self.pos (7, 1)
# self.movement  F move  F
# self.next pos (7, 2)
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 5)
# soy 1 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (8, 4)
# self.movement  F move  F
# self.next pos (8, 3)
# self.pos (10, 6)
# self.movement  TL move  F
# self.next pos (9, 6)
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 4 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals [1]
# signals []
# signals []
# signals [3]
# queue ['trafLight Inf Left', 'trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right']
# self.pos (7, 2)
# self.movement  F move  F
# self.next pos (7, 3)
# self.pos (7, 5)
# self.movement  F move  S
# self.next pos (7, 5)
# self.pos (8, 3)
# self.movement  F move  F
# self.next pos (8, 2)
# self.pos (9, 6)
# self.movement  F move  TL
# self.next pos (9, 5)
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 4 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 3)
# soy 0 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (7, 5)
# self.movement  F move  F
# self.next pos (7, 6)
# self.pos (8, 2)
# self.movement  F move  F
# self.next pos (8, 1)
# self.pos (9, 5)
# self.movement  F move  F
# self.next pos (9, 4)
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 5)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 0 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (7, 6)
# self.movement  F move  F
# self.next pos (7, 7)
# self.pos (8, 1)
# self.movement  F move  F
# self.next pos (8, 0)
# self.pos (9, 4)
# self.movement  F move  F
# self.next pos (9, 3)
# self.pos (7, 5)
# self.movement  TR move  F
# self.next pos (7, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4, 0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 5)
# self.pos (7, 7)
# self.movement  F move  F
# self.next pos (7, 8)
# self.pos (8, 0)
# self.movement  F move  F
# self.next pos (8, -1)
# self.pos (9, 3)
# self.movement  F move  F
# self.next pos (9, 2)
# self.pos (7, 6)
# self.movement  TR move  F
# self.next pos (7, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4, 0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 5)
# self.movement  F move  F
# self.next pos (7, 6)
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (7, 9)
# self.pos (8, 15)
# self.movement  F move  F
# self.next pos (8, 14)
# self.pos (9, 2)
# self.movement  F move  F
# self.next pos (9, 1)
# self.pos (7, 7)
# self.movement  TR move  F
# self.next pos (7, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4, 0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 6)
# self.movement  F move  F
# self.next pos (7, 7)
# self.pos (7, 9)
# self.movement  F move  F
# self.next pos (7, 10)
# self.pos (8, 14)
# self.movement  F move  F
# self.next pos (8, 13)
# self.pos (9, 1)
# self.movement  F move  F
# self.next pos (9, 0)
# self.pos (7, 8)
# self.movement  F move  TR
# self.next pos (8, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 4, 0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 7)
# self.movement  F move  F
# self.next pos (7, 8)
# self.pos (7, 10)
# self.movement  F move  F
# self.next pos (7, 11)
# self.pos (8, 13)
# self.movement  F move  F
# self.next pos (8, 12)
# self.pos (9, 0)
# self.movement  F move  F
# self.next pos (9, -1)
# self.pos (8, 8)
# self.movement  F move  F
# self.next pos (9, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [4, 0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 8)
# self.movement  F move  F
# self.next pos (7, 9)
# self.pos (7, 11)
# self.movement  F move  F
# self.next pos (7, 12)
# self.pos (8, 12)
# self.movement  F move  F
# self.next pos (8, 11)
# soy 2 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (9, 15)
# self.movement  F move  F
# self.next pos (9, 14)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (10, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Inf Right', 'trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 9)
# self.movement  F move  F
# self.next pos (7, 10)
# self.pos (7, 12)
# self.movement  F move  F
# self.next pos (7, 13)
# self.pos (8, 11)
# self.movement  F move  F
# self.next pos (8, 10)
# soy 2 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (9, 14)
# self.movement  F move  F
# self.next pos (9, 13)
# self.pos (10, 8)
# self.movement  F move  F
# self.next pos (11, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals []
# signals [2]
# signals []
# queue ['trafLight Sup Left', 'trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 10)
# self.movement  F move  F
# self.next pos (7, 11)
# self.pos (7, 13)
# self.movement  F move  F
# self.next pos (7, 14)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 13)
# self.movement  F move  F
# self.next pos (9, 12)
# self.pos (11, 8)
# self.movement  F move  F
# self.next pos (12, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 11)
# self.movement  F move  F
# self.next pos (7, 12)
# self.pos (7, 14)
# self.movement  F move  F
# self.next pos (7, 15)
# self.pos (8, 10)
# self.movement  F move  F
# self.next pos (8, 9)
# self.pos (9, 12)
# self.movement  F move  F
# self.next pos (9, 11)
# soy 3 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (12, 8)
# self.movement  F move  F
# self.next pos (13, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 12)
# self.movement  F move  F
# self.next pos (7, 13)
# self.pos (7, 15)
# self.movement  F move  F
# self.next pos (7, 16)
# self.pos (8, 9)
# self.movement  F move  F
# self.next pos (8, 8)
# self.pos (9, 11)
# self.movement  F move  F
# self.next pos (9, 10)
# soy 3 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (13, 8)
# self.movement  F move  F
# self.next pos (14, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 13)
# self.movement  F move  F
# self.next pos (7, 14)
# self.pos (7, 0)
# self.movement  F move  F
# self.next pos (7, 1)
# self.pos (8, 8)
# self.movement  F move  F
# self.next pos (8, 7)
# self.pos (9, 10)
# self.movement  F move  F
# self.next pos (9, 9)
# self.pos (14, 8)
# self.movement  F move  F
# self.next pos (15, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 14)
# self.movement  F move  F
# self.next pos (7, 15)
# self.pos (7, 1)
# self.movement  F move  F
# self.next pos (7, 2)
# self.pos (8, 7)
# self.movement  F move  F
# self.next pos (8, 6)
# self.pos (9, 9)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (15, 8)
# self.movement  F move  F
# self.next pos (16, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 15)
# self.movement  F move  F
# self.next pos (7, 16)
# self.pos (7, 2)
# self.movement  F move  F
# self.next pos (7, 3)
# self.pos (8, 6)
# self.movement  F move  F
# self.next pos (8, 5)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (9, 7)
# self.pos (0, 8)
# self.movement  F move  F
# self.next pos (1, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals []
# queue ['trafLight Inf Right']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Sup Left']
# self.pos (7, 0)
# self.movement  F move  F
# self.next pos (7, 1)
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 1 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (8, 5)
# self.movement  F move  F
# self.next pos (8, 4)
# self.pos (9, 7)
# self.movement  F move  F
# self.next pos (9, 6)
# self.pos (1, 8)
# self.movement  F move  F
# self.next pos (2, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [1]
# signals []
# signals [3]
# signals []
# queue ['trafLight Inf Right', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 1)
# self.movement  F move  F
# self.next pos (7, 2)
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 5)
# self.pos (8, 4)
# self.movement  F move  F
# self.next pos (8, 3)
# self.pos (9, 6)
# self.movement  F move  F
# self.next pos (9, 5)
# self.pos (2, 8)
# self.movement  F move  F
# self.next pos (3, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [1]
# signals []
# signals [3]
# signals []
# queue ['trafLight Inf Right', 'trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Left']
# self.pos (7, 2)
# self.movement  F move  F
# self.next pos (7, 3)
# self.pos (7, 5)
# self.movement  F move  S
# self.next pos (7, 5)
# self.pos (8, 3)
# self.movement  F move  F
# self.next pos (8, 2)
# self.pos (9, 5)
# self.movement  F move  F
# self.next pos (9, 4)
# self.pos (3, 8)
# self.movement  F move  F
# self.next pos (4, 8)
# soy 4 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals [1]
# signals []
# signals []
# signals []
# queue ['trafLight Sup Left']
# free ['trafLight Sup Right', 'trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 3)
# self.movement  F move  F
# self.next pos (7, 4)
# soy 0 y el semáforo que me toca es  trafLight Sup Left 0 y envie señal
# self.pos (7, 5)
# self.movement  TL move  C
# self.next pos (6, 5)
# self.pos (8, 2)
# self.movement  F move  F
# self.next pos (8, 1)
# self.pos (9, 4)
# self.movement  F move  F
# self.next pos (9, 3)
# self.pos (4, 8)
# self.movement  F move  F
# self.next pos (5, 8)
# soy 4 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 4)
# self.movement  F move  F
# self.next pos (7, 5)
# self.pos (6, 5)
# self.movement  TL move  F
# self.next pos (6, 6)
# self.pos (8, 1)
# self.movement  F move  F
# self.next pos (8, 0)
# self.pos (9, 3)
# self.movement  F move  F
# self.next pos (9, 2)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [1, 0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 5)
# self.movement  TR move  F
# self.next pos (7, 6)
# self.pos (6, 6)
# self.movement  F move  TL
# self.next pos (5, 6)
# self.pos (8, 0)
# self.movement  F move  F
# self.next pos (8, -1)
# self.pos (9, 2)
# self.movement  F move  F
# self.next pos (9, 1)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 6)
# self.movement  TR move  F
# self.next pos (7, 7)
# self.pos (5, 6)
# self.movement  F move  F
# self.next pos (4, 6)
# self.pos (8, 15)
# self.movement  F move  F
# self.next pos (8, 14)
# self.pos (9, 1)
# self.movement  F move  F
# self.next pos (9, 0)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 7)
# self.movement  TR move  F
# self.next pos (7, 8)
# self.pos (4, 6)
# self.movement  F move  F
# self.next pos (3, 6)
# self.pos (8, 14)
# self.movement  F move  F
# self.next pos (8, 13)
# self.pos (9, 0)
# self.movement  F move  F
# self.next pos (9, -1)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (7, 8)
# self.movement  F move  TR
# self.next pos (8, 8)
# self.pos (3, 6)
# self.movement  F move  F
# self.next pos (2, 6)
# self.pos (8, 13)
# self.movement  F move  F
# self.next pos (8, 12)
# self.pos (9, 15)
# self.movement  F move  F
# self.next pos (9, 14)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [4]
# signals []
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right']
# free ['trafLight Inf Left', 'trafLight Inf Right']
# self.pos (8, 8)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (2, 6)
# self.movement  F move  F
# self.next pos (1, 6)
# self.pos (8, 12)
# self.movement  F move  F
# self.next pos (8, 11)
# soy 2 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (9, 14)
# self.movement  F move  F
# self.next pos (9, 13)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals [0]
# signals [4]
# signals [2]
# signals []
# queue ['trafLight Sup Left', 'trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left']
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (10, 8)
# self.pos (1, 6)
# self.movement  F move  F
# self.next pos (0, 6)
# self.pos (8, 11)
# self.movement  F move  F
# self.next pos (8, 10)
# self.pos (9, 13)
# self.movement  F move  F
# self.next pos (9, 12)
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (10, 8)
# self.movement  F move  F
# self.next pos (11, 8)
# self.pos (0, 6)
# self.movement  F move  F
# self.next pos (-1, 6)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 12)
# self.movement  F move  F
# self.next pos (9, 11)
# soy 3 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# self.pos (5, 8)
# self.movement  TR move  F
# self.next pos (6, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2, 3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (11, 8)
# self.movement  F move  F
# self.next pos (12, 8)
# self.pos (15, 6)
# self.movement  F move  F
# self.next pos (14, 6)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 11)
# self.movement  F move  F
# self.next pos (9, 10)
# self.pos (6, 8)
# self.movement  TR move  F
# self.next pos (7, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2, 3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (12, 8)
# self.movement  F move  F
# self.next pos (13, 8)
# self.pos (14, 6)
# self.movement  F move  F
# self.next pos (13, 6)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (7, 8)
# self.movement  TR move  F
# self.next pos (8, 8)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2, 3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (13, 8)
# self.movement  F move  F
# self.next pos (14, 8)
# self.pos (13, 6)
# self.movement  F move  F
# self.next pos (12, 6)
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (8, 8)
# self.movement  F move  TR
# self.next pos (8, 7)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2, 3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (14, 8)
# self.movement  F move  F
# self.next pos (15, 8)
# self.pos (12, 6)
# self.movement  F move  F
# self.next pos (11, 6)
# soy 1 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (8, 7)
# self.movement  F move  F
# self.next pos (8, 6)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [4]
# signals [2, 3]
# signals []
# queue ['trafLight Sup Right', 'trafLight Inf Right']
# free ['trafLight Inf Left', 'trafLight Sup Left']
# self.pos (15, 8)
# self.movement  F move  F
# self.next pos (16, 8)
# self.pos (11, 6)
# self.movement  F move  F
# self.next pos (10, 6)
# soy 1 y el semáforo que me toca es  trafLight Inf Left 3 y envie señal
# self.pos (8, 10)
# self.movement  F move  S
# self.next pos (8, 10)
# self.pos (9, 10)
# self.movement  F move  S
# self.next pos (9, 10)
# self.pos (8, 6)
# self.movement  F move  F
# self.next pos (8, 5)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (0, 8)
# self.movement  F move  F
# self.next pos (1, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (8, 10)
# self.movement  TR move  F
# self.next pos (8, 9)
# self.pos (9, 10)
# self.movement  F move  F
# self.next pos (9, 9)
# self.pos (8, 5)
# self.movement  F move  F
# self.next pos (8, 4)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (1, 8)
# self.movement  F move  F
# self.next pos (2, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (8, 9)
# self.movement  TR move  F
# self.next pos (8, 8)
# self.pos (9, 9)
# self.movement  F move  F
# self.next pos (9, 8)
# self.pos (8, 4)
# self.movement  F move  F
# self.next pos (8, 3)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (2, 8)
# self.movement  F move  F
# self.next pos (3, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (8, 8)
# self.movement  TR move  F
# self.next pos (8, 7)
# self.pos (9, 8)
# self.movement  F move  F
# self.next pos (9, 7)
# self.pos (8, 3)
# self.movement  F move  F
# self.next pos (8, 2)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (3, 8)
# self.movement  F move  F
# self.next pos (4, 8)
# soy 0 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (8, 7)
# self.movement  F move  TR
# self.next pos (7, 7)
# self.pos (9, 7)
# self.movement  F move  F
# self.next pos (9, 6)
# self.pos (8, 2)
# self.movement  F move  F
# self.next pos (8, 1)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals []
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left']
# free ['trafLight Sup Left', 'trafLight Sup Right']
# self.pos (4, 8)
# self.movement  F move  F
# self.next pos (5, 8)
# soy 0 y el semáforo que me toca es  trafLight Sup Right 1 y envie señal
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (7, 7)
# self.movement  F move  F
# self.next pos (6, 7)
# self.pos (9, 6)
# self.movement  F move  F
# self.next pos (9, 5)
# self.pos (8, 1)
# self.movement  F move  F
# self.next pos (8, 0)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals [2, 3]
# signals [1]
# queue ['trafLight Inf Right', 'trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left']
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (10, 6)
# self.movement  F move  S
# self.next pos (10, 6)
# self.pos (6, 7)
# self.movement  F move  F
# self.next pos (5, 7)
# self.pos (9, 5)
# self.movement  F move  F
# self.next pos (9, 4)
# self.pos (8, 0)
# self.movement  F move  F
# self.next pos (8, -1)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals []
# signals [1]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (10, 6)
# self.movement  TL move  F
# self.next pos (9, 6)
# self.pos (5, 7)
# self.movement  F move  F
# self.next pos (4, 7)
# self.pos (9, 4)
# self.movement  F move  F
# self.next pos (9, 3)
# self.pos (8, 15)
# self.movement  F move  F
# self.next pos (8, 14)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals []
# signals [1]
# queue ['trafLight Inf Left', 'trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right']
# self.pos (5, 8)
# self.movement  F move  S
# self.next pos (5, 8)
# self.pos (9, 6)
# self.movement  F move  TL
# self.next pos (9, 5)
# self.pos (4, 7)
# self.movement  F move  F
# self.next pos (3, 7)
# self.pos (9, 3)
# self.movement  F move  F
# self.next pos (9, 2)
# self.pos (8, 14)
# self.movement  F move  F
# self.next pos (8, 13)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (5, 8)
# self.movement  TL move  C
# self.next pos (5, 9)
# self.pos (9, 5)
# self.movement  F move  F
# self.next pos (9, 4)
# self.pos (3, 7)
# self.movement  F move  F
# self.next pos (2, 7)
# self.pos (9, 2)
# self.movement  F move  F
# self.next pos (9, 1)
# self.pos (8, 13)
# self.movement  F move  F
# self.next pos (8, 12)
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (5, 9)
# self.movement  TL move  F
# self.next pos (6, 9)
# self.pos (9, 4)
# self.movement  F move  F
# self.next pos (9, 3)
# self.pos (2, 7)
# self.movement  F move  F
# self.next pos (1, 7)
# self.pos (9, 1)
# self.movement  F move  F
# self.next pos (9, 0)
# self.pos (8, 12)
# self.movement  F move  F
# self.next pos (8, 11)
# soy 4 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# iter --------------------------------------
# iter --------------------------------------
# signals []
# signals [0]
# signals []
# signals []
# queue ['trafLight Sup Right']
# free ['trafLight Sup Left', 'trafLight Inf Right', 'trafLight Inf Left']
# self.pos (6, 9)
# self.movement  F move  TL
# self.next pos (6, 10)
# self.pos (9, 3)
# self.movement  F move  F
# self.next pos (9, 2)
# self.pos (1, 7)
# self.movement  F move  F
# self.next pos (0, 7)
# self.pos (9, 0)
# self.movement  F move  F
# self.next pos (9, -1)
# self.pos (8, 11)
# self.movement  F move  F
# self.next pos (8, 10)
# soy 4 y el semáforo que me toca es  trafLight Inf Right 2 y envie señal
# iter --------------------------------------

# %% [markdown]
# Obtenemos la información que almacenó el colector, este nos entregará un DataFrame de pandas que contiene toda la información.

# %%
all_grid = model.datacollector.get_model_vars_dataframe()

# %% [markdown]
# Graficamos la información usando matplotlib

# %%
# %%capture

fig, axs = plt.subplots(figsize=(7,7))
axs.set_xticks([])
axs.set_yticks([])
patch = plt.imshow(all_grid.iloc[0][0], cmap=plt.colormaps["gist_ncar"])

def animate(i):
    patch.set_data(all_grid.iloc[i][0])
    
anim = animation.FuncAnimation(fig, animate, frames=num_generations)

# %%
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img013fa4515bca498fb3af6d1e772aa13a">
#   <div class="anim-controls">
#     <input id="_anim_slider013fa4515bca498fb3af6d1e772aa13a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim013fa4515bca498fb3af6d1e772aa13a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim013fa4515bca498fb3af6d1e772aa13a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim013fa4515bca498fb3af6d1e772aa13a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim013fa4515bca498fb3af6d1e772aa13a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim013fa4515bca498fb3af6d1e772aa13a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim013fa4515bca498fb3af6d1e772aa13a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim013fa4515bca498fb3af6d1e772aa13a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim013fa4515bca498fb3af6d1e772aa13a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim013fa4515bca498fb3af6d1e772aa13a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim013fa4515bca498fb3af6d1e772aa13a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select013fa4515bca498fb3af6d1e772aa13a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_013fa4515bca498fb3af6d1e772aa13a"
#              >
#       <label for="_anim_radio1_013fa4515bca498fb3af6d1e772aa13a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_013fa4515bca498fb3af6d1e772aa13a"
#              checked>
#       <label for="_anim_radio2_013fa4515bca498fb3af6d1e772aa13a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_013fa4515bca498fb3af6d1e772aa13a"
#              >
#       <label for="_anim_radio3_013fa4515bca498fb3af6d1e772aa13a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img013fa4515bca498fb3af6d1e772aa13a";
#     var slider_id = "_anim_slider013fa4515bca498fb3af6d1e772aa13a";
#     var loop_select_id = "_anim_loop_select013fa4515bca498fb3af6d1e772aa13a";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjYuMSwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/av/WaAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAAOv0lE
